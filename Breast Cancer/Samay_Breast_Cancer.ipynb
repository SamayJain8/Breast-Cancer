# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df_cancer = pd.read_csv('/data.csv')
df_cancer.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming df_cancer is your DataFrame and 'diagnosis' is the column
le = LabelEncoder()
df_cancer['diagnosis'] = le.fit_transform(df_cancer['diagnosis'])

# %%
df_cancer
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %%
df_cancer['diagnosis'].value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# **CORRELATION B/W FEATURES**

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df_cancer.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# **Model Training**

# %%
X = df_cancer.drop(['diagnosis'], axis = 1) # We drop our "target" feature and use all the remaining features in our dataframe to train the model.
X.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
y = df_cancer['diagnosis']
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: diagnosis, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 20)

# %%
from sklearn.svm import SVC
svc_model = SVC()

# %%
svc_model.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_predict = svc_model.predict(X_test)

# %%
# Import metric libraries

from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.73        66
#            1       0.00      0.00      0.00        48
#
#     accuracy                           0.58       114
#    macro avg       0.29      0.50      0.37       114
# weighted avg       0.34      0.58      0.42       114
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# ## **Improving the model**

# %% [markdown]
# **Normalization**

# %%
X_train_min = X_train.min()
X_train_max = X_train.max()
X_train_range = (X_train_max- X_train_min)

# %%
X_train_scaled = (X_train - X_train_min)/(X_train_range)
X_train_scaled.head()
# Out:
#            id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 412  0.000984     0.114345      0.391003        0.110290   0.053150
# 461  0.999973     0.967343      0.549827        0.988943   1.000000
# 532  0.100838     0.317052      0.205882        0.303849   0.183245
# 495  0.000994     0.373373      0.340138        0.361620   0.227953
# 13   0.000919     0.419755      0.469550        0.414000   0.271135
#
#      smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 412         0.293907          0.126219        0.087512             0.025487
# 461         0.605735          0.550334        0.851687             0.839463
# 532         0.435973          0.163088        0.041050             0.093439
# 495         0.469643          0.196522        0.159888             0.246074
# 13          0.340828          0.247899        0.232849             0.266600
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
X_test_min = X_test.min()
X_test_range = (X_test - X_test_min).max()
X_test_scaled = (X_test - X_test_min)/X_test_range

# %%
svc_model = SVC()
svc_model.fit(X_train_scaled, y_train)
# Out:
# SVC()

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        66
#            1       0.92      1.00      0.96        48
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.97      0.96       114
# weighted avg       0.97      0.96      0.97       114
